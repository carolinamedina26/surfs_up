# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
        
#"Current Description": city_weather_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | sorong
# Processing Record 3 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | sherlovaya gora
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | svetlyy
# Processing Record 11 of Set 1 | anadyr
# Processing Record 12 of Set 1 | cap-aux-meules
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | beatrice
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | kashan
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | qitaihe
# Processing Record 28 of Set 1 | saint john
# Processing Record 29 of Set 1 | kalmunai
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | maues
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | palmer
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | ayer itam
# City not found. Skipping...
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | trairi
# Processing Record 40 of Set 1 | ostrovnoy
# Processing Record 41 of Set 1 | parana
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | kayes
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | aksarayskiy
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | trelew
# Processing Record 48 of Set 1 | presidencia roque saenz pena
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 2 | inhambane
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | kamaishi
# Processing Record 9 of Set 2 | tessalit
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | antofagasta
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | constitucion
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | kavaratti
# Processing Record 27 of Set 2 | polunochnoye
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | arman
# Processing Record 31 of Set 2 | dubbo
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | bandrele
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | tiarei
# Processing Record 36 of Set 2 | eravur
# Processing Record 37 of Set 2 | mombetsu
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | karpogory
# Processing Record 43 of Set 2 | palmeirais
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | kon tum
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | flin flon
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | toktogul
# Processing Record 2 of Set 3 | konevo
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | anori
# Processing Record 6 of Set 3 | kieta
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | nome
# Processing Record 10 of Set 3 | alenquer
# Processing Record 11 of Set 3 | vanimo
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | briancon
# Processing Record 14 of Set 3 | sindor
# Processing Record 15 of Set 3 | ciudad bolivar
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | punta alta
# Processing Record 18 of Set 3 | ginir
# Processing Record 19 of Set 3 | taitung
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | rafai
# Processing Record 22 of Set 3 | nuuk
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | caravelas
# Processing Record 25 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 3 | aswan
# Processing Record 27 of Set 3 | aykhal
# Processing Record 28 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 3 | mwene-ditu
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | port-cartier
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | cabatuan
# Processing Record 34 of Set 3 | truckee
# Processing Record 35 of Set 3 | churapcha
# Processing Record 36 of Set 3 | hami
# Processing Record 37 of Set 3 | kushmurun
# Processing Record 38 of Set 3 | egvekinot
# Processing Record 39 of Set 3 | zhezkazgan
# Processing Record 40 of Set 3 | makueni
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | saint-francois
# Processing Record 43 of Set 3 | husavik
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | shimoni
# Processing Record 46 of Set 3 | la plata
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 3 | taoudenni
# Processing Record 1 of Set 4 | pio ix
# Processing Record 2 of Set 4 | imbituba
# Processing Record 3 of Set 4 | ballina
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | bemidji
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | santa isabel do rio negro
# Processing Record 8 of Set 4 | severo-yeniseyskiy
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | port hardy
# Processing Record 11 of Set 4 | sandy bay
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | lukovetskiy
# Processing Record 16 of Set 4 | chiredzi
# Processing Record 17 of Set 4 | goderich
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | nalut
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | pendencias
# Processing Record 24 of Set 4 | moshenskoye
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | okhotsk
# Processing Record 28 of Set 4 | balakhninskiy
# Processing Record 29 of Set 4 | college
# Processing Record 30 of Set 4 | jiangyou
# Processing Record 31 of Set 4 | visby
# Processing Record 32 of Set 4 | krutinka
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | praia da vitoria
# Processing Record 36 of Set 4 | iqaluit
# Processing Record 37 of Set 4 | kembe
# Processing Record 38 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | buala
# Processing Record 41 of Set 4 | gornopravdinsk
# Processing Record 42 of Set 4 | tromso
# Processing Record 43 of Set 4 | pergamino
# Processing Record 44 of Set 4 | cherskiy
# Processing Record 45 of Set 4 | margate
# Processing Record 46 of Set 4 | kostomuksha
# Processing Record 47 of Set 4 | quatre cocos
# Processing Record 48 of Set 4 | colac
# Processing Record 49 of Set 4 | maxixe
# Processing Record 50 of Set 4 | izumo
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | nagold
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | ratnagiri
# Processing Record 6 of Set 5 | mazulskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | galveston
# Processing Record 9 of Set 5 | amapa
# Processing Record 10 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 5 | yellowknife
# Processing Record 12 of Set 5 | quang ngai
# Processing Record 13 of Set 5 | creel
# Processing Record 14 of Set 5 | yulara
# Processing Record 15 of Set 5 | lubango
# Processing Record 16 of Set 5 | salvador
# Processing Record 17 of Set 5 | kiama
# Processing Record 18 of Set 5 | doha
# Processing Record 19 of Set 5 | ewo
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | usinsk
# Processing Record 22 of Set 5 | dolores
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | qasigiannguit
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | san fernando
# Processing Record 27 of Set 5 | mezen
# Processing Record 28 of Set 5 | thatta
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | lasa
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | sembe
# Processing Record 33 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | rio grande
# Processing Record 36 of Set 5 | atar
# Processing Record 37 of Set 5 | isangel
# Processing Record 38 of Set 5 | shimoda
# Processing Record 39 of Set 5 | jamestown
# Processing Record 40 of Set 5 | belyy yar
# Processing Record 41 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 42 of Set 5 | bom jardim
# Processing Record 43 of Set 5 | sur
# Processing Record 44 of Set 5 | sangar
# Processing Record 45 of Set 5 | bud
# Processing Record 46 of Set 5 | havelock
# Processing Record 47 of Set 5 | jiuquan
# Processing Record 48 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 49 of Set 5 | augusto correa
# Processing Record 50 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 6 | brae
# Processing Record 2 of Set 6 | kupang
# Processing Record 3 of Set 6 | provideniya
# Processing Record 4 of Set 6 | maniitsoq
# Processing Record 5 of Set 6 | newcastle
# Processing Record 6 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 6 | teguise
# Processing Record 8 of Set 6 | saint anthony
# Processing Record 9 of Set 6 | starodubskoye
# Processing Record 10 of Set 6 | dalmatovo
# Processing Record 11 of Set 6 | karpuninskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | sidney
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | takoradi
# Processing Record 16 of Set 6 | torbay
# Processing Record 17 of Set 6 | mount darwin
# Processing Record 18 of Set 6 | payo
# Processing Record 19 of Set 6 | vinh
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | sorland
# Processing Record 23 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 24 of Set 6 | sonepur
# Processing Record 25 of Set 6 | callaguip
# Processing Record 26 of Set 6 | busia
# Processing Record 27 of Set 6 | kloulklubed
# Processing Record 28 of Set 6 | bam
# Processing Record 29 of Set 6 | coihaique
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | sept-iles
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | turkan
# Processing Record 34 of Set 6 | wilmington island
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | sabang
# Processing Record 37 of Set 6 | san felipe
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 6 | ahvaz
# Processing Record 41 of Set 6 | pacific grove
# Processing Record 42 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 6 | yatou
# Processing Record 44 of Set 6 | kurilsk
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | mantua
# Processing Record 47 of Set 6 | champerico
# Processing Record 48 of Set 6 | quchan
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | coahuayana
# Processing Record 1 of Set 7 | remanso
# Processing Record 2 of Set 7 | acapulco
# Processing Record 3 of Set 7 | dargaville
# Processing Record 4 of Set 7 | bubaque
# Processing Record 5 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 7 | leh
# Processing Record 7 of Set 7 | san quintin
# Processing Record 8 of Set 7 | roald
# Processing Record 9 of Set 7 | kaeo
# Processing Record 10 of Set 7 | puerto leguizamo
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | muisne
# Processing Record 13 of Set 7 | dongsheng
# Processing Record 14 of Set 7 | thunder bay
# Processing Record 15 of Set 7 | westlock
# Processing Record 16 of Set 7 | haines junction
# Processing Record 17 of Set 7 | veraval
# Processing Record 18 of Set 7 | uniao da victoria
# City not found. Skipping...
# Processing Record 19 of Set 7 | samarkand
# Processing Record 20 of Set 7 | tual
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | sestri levante
# Processing Record 24 of Set 7 | aksarka
# Processing Record 25 of Set 7 | kaniv
# Processing Record 26 of Set 7 | tucuman
# Processing Record 27 of Set 7 | kaseda
# Processing Record 28 of Set 7 | codrington
# Processing Record 29 of Set 7 | denpasar
# Processing Record 30 of Set 7 | krasnyy chikoy
# Processing Record 31 of Set 7 | olafsvik
# Processing Record 32 of Set 7 | chardara
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | linhares
# Processing Record 35 of Set 7 | petatlan
# Processing Record 36 of Set 7 | bangolo
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | the valley
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | kirksville
# Processing Record 41 of Set 7 | maceio
# Processing Record 42 of Set 7 | viseu
# Processing Record 43 of Set 7 | srednekolymsk
# Processing Record 44 of Set 7 | kysyl-syr
# Processing Record 45 of Set 7 | westport
# Processing Record 46 of Set 7 | moen
# Processing Record 47 of Set 7 | el angel
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | amboasary
# Processing Record 50 of Set 7 | ponta do sol
# Processing Record 1 of Set 8 | coos bay
# Processing Record 2 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 8 | catamarca
# Processing Record 4 of Set 8 | skjervoy
# Processing Record 5 of Set 8 | noumea
# Processing Record 6 of Set 8 | bilma
# Processing Record 7 of Set 8 | poum
# Processing Record 8 of Set 8 | airai
# Processing Record 9 of Set 8 | alofi
# Processing Record 10 of Set 8 | bonthe
# Processing Record 11 of Set 8 | guilin
# Processing Record 12 of Set 8 | morant bay
# Processing Record 13 of Set 8 | gat
# Processing Record 14 of Set 8 | joaquim nabuco
# Processing Record 15 of Set 8 | san luis
# Processing Record 16 of Set 8 | taywarah
# Processing Record 17 of Set 8 | santarem
# Processing Record 18 of Set 8 | naze
# Processing Record 19 of Set 8 | bloomington
# Processing Record 20 of Set 8 | ayr
# Processing Record 21 of Set 8 | lazi
# Processing Record 22 of Set 8 | marzuq
# Processing Record 23 of Set 8 | chuy
# Processing Record 24 of Set 8 | jalu
# Processing Record 25 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 8 | whithorn
# Processing Record 27 of Set 8 | deputatskiy
# Processing Record 28 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 8 | nadym
# Processing Record 30 of Set 8 | havoysund
# Processing Record 31 of Set 8 | kulhudhuffushi
# Processing Record 32 of Set 8 | orodara
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | irati
# Processing Record 35 of Set 8 | alihe
# Processing Record 36 of Set 8 | entebbe
# Processing Record 37 of Set 8 | san jose
# Processing Record 38 of Set 8 | boyolangu
# Processing Record 39 of Set 8 | carroll
# Processing Record 40 of Set 8 | saint-paul
# Processing Record 41 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 42 of Set 8 | cap malheureux
# Processing Record 43 of Set 8 | mayo
# Processing Record 44 of Set 8 | ust-kuyga
# Processing Record 45 of Set 8 | manyana
# Processing Record 46 of Set 8 | kenai
# Processing Record 47 of Set 8 | birao
# Processing Record 48 of Set 8 | nouadhibou
# Processing Record 49 of Set 8 | tura
# Processing Record 50 of Set 8 | berlevag
# Processing Record 1 of Set 9 | tabas
# Processing Record 2 of Set 9 | ulundi
# Processing Record 3 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 9 | burnie
# Processing Record 6 of Set 9 | seoul
# Processing Record 7 of Set 9 | kuhestan
# City not found. Skipping...
# Processing Record 8 of Set 9 | ust-shonosha
# Processing Record 9 of Set 9 | kisangani
# Processing Record 10 of Set 9 | araouane
# Processing Record 11 of Set 9 | ewa beach
# Processing Record 12 of Set 9 | santa vitoria do palmar
# Processing Record 13 of Set 9 | porto novo
# Processing Record 14 of Set 9 | los llanos de aridane
# Processing Record 15 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 9 | saint-georges
# Processing Record 17 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 9 | vostok
# Processing Record 19 of Set 9 | malakal
# Processing Record 20 of Set 9 | champasak
# Processing Record 21 of Set 9 | alkhan-kala
# Processing Record 22 of Set 9 | mehamn
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 9 | morropon
# Processing Record 26 of Set 9 | launceston
# Processing Record 27 of Set 9 | sistranda
# Processing Record 28 of Set 9 | zeerust
# Processing Record 29 of Set 9 | tuatapere
# Processing Record 30 of Set 9 | tilichiki
# Processing Record 31 of Set 9 | octeville
# Processing Record 32 of Set 9 | chapais
# Processing Record 33 of Set 9 | dumbarton
# Processing Record 34 of Set 9 | hobbs
# Processing Record 35 of Set 9 | peniche
# Processing Record 36 of Set 9 | leshukonskoye
# Processing Record 37 of Set 9 | sambava
# Processing Record 38 of Set 9 | funehiki
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | lamu
# Processing Record 41 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 42 of Set 9 | tecoanapa
# Processing Record 43 of Set 9 | payakumbuh
# Processing Record 44 of Set 9 | thinadhoo
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | leningradskiy
# Processing Record 47 of Set 9 | gorshechnoye
# Processing Record 48 of Set 9 | sipoo
# Processing Record 49 of Set 9 | teya
# Processing Record 50 of Set 9 | mari-turek
# Processing Record 1 of Set 10 | cody
# Processing Record 2 of Set 10 | suez
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | gobabis
# Processing Record 7 of Set 10 | ixtapa
# Processing Record 8 of Set 10 | sant julia de loria
# Processing Record 9 of Set 10 | estelle
# Processing Record 10 of Set 10 | lobito
# Processing Record 11 of Set 10 | svetlogorsk
# Processing Record 12 of Set 10 | belen
# Processing Record 13 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 10 | ravar
# Processing Record 15 of Set 10 | maryville
# Processing Record 16 of Set 10 | urucara
# Processing Record 17 of Set 10 | plettenberg bay
# Processing Record 18 of Set 10 | jiujiang
# Processing Record 19 of Set 10 | ovalle
# Processing Record 20 of Set 10 | mazara del vallo
# Processing Record 21 of Set 10 | storozhevaya
# Processing Record 22 of Set 10 | mackay
# Processing Record 23 of Set 10 | dharchula
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | vadso
# Processing Record 26 of Set 10 | savyntsi
# Processing Record 27 of Set 10 | kiruna
# Processing Record 28 of Set 10 | narita
# Processing Record 29 of Set 10 | korla
# Processing Record 30 of Set 10 | fairbanks
# Processing Record 31 of Set 10 | terra nova
# Processing Record 32 of Set 10 | teluknaga
# Processing Record 33 of Set 10 | puerto escondido
# Processing Record 34 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 10 | mukdahan
# Processing Record 36 of Set 10 | play cu
# City not found. Skipping...
# Processing Record 37 of Set 10 | pocone
# Processing Record 38 of Set 10 | mackenzie
# Processing Record 39 of Set 10 | warri
# Processing Record 40 of Set 10 | san ramon
# Processing Record 41 of Set 10 | dwarka
# Processing Record 42 of Set 10 | iroquois falls
# Processing Record 43 of Set 10 | manuk mangkaw
# Processing Record 44 of Set 10 | pauini
# Processing Record 45 of Set 10 | basmat
# Processing Record 46 of Set 10 | san policarpo
# Processing Record 47 of Set 10 | madison heights
# Processing Record 48 of Set 10 | lahij
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 50 of Set 10 | moranbah
# Processing Record 1 of Set 11 | makakilo city
# Processing Record 2 of Set 11 | morro bay
# Processing Record 3 of Set 11 | hervey bay
# Processing Record 4 of Set 11 | nyurba
# Processing Record 5 of Set 11 | baijiantan
# Processing Record 6 of Set 11 | asmar
# Processing Record 7 of Set 11 | asau
# Processing Record 8 of Set 11 | chippewa falls
# Processing Record 9 of Set 11 | moron
# Processing Record 10 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 11 | altay
# Processing Record 12 of Set 11 | tiznit
# Processing Record 13 of Set 11 | huambo
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | mirnyy
# Processing Record 16 of Set 11 | apatou
# Processing Record 17 of Set 11 | krasnoarmeysk
# Processing Record 18 of Set 11 | byron bay
# Processing Record 19 of Set 11 | waipawa
# Processing Record 20 of Set 11 | baker city
# Processing Record 21 of Set 11 | plouzane
# Processing Record 22 of Set 11 | benjamin constant
# Processing Record 23 of Set 11 | hualmay
# Processing Record 24 of Set 11 | andenes
# Processing Record 25 of Set 11 | callaway
# Processing Record 26 of Set 11 | eureka
# Processing Record 27 of Set 11 | samarai
# Processing Record 28 of Set 11 | alyangula
# Processing Record 29 of Set 11 | karratha
# Processing Record 30 of Set 11 | aripuana
# Processing Record 31 of Set 11 | general roca
# Processing Record 32 of Set 11 | elat
# Processing Record 33 of Set 11 | pangkalanbuun
# Processing Record 34 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 35 of Set 11 | cabedelo
# Processing Record 36 of Set 11 | lorengau
# Processing Record 37 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 11 | mashhad
# Processing Record 39 of Set 11 | erzin
# Processing Record 40 of Set 11 | qostanay
# Processing Record 41 of Set 11 | guntur
# Processing Record 42 of Set 11 | wenchi
# Processing Record 43 of Set 11 | valparaiso
# Processing Record 44 of Set 11 | hisor
# Processing Record 45 of Set 11 | tazmalt
# Processing Record 46 of Set 11 | rio tuba
# Processing Record 47 of Set 11 | nemuro
# Processing Record 48 of Set 11 | sarangani
# Processing Record 49 of Set 11 | noyabrsk
# Processing Record 50 of Set 11 | igrim
# Processing Record 1 of Set 12 | pangody
# Processing Record 2 of Set 12 | yankton
# Processing Record 3 of Set 12 | troy
# Processing Record 4 of Set 12 | kakrala
# Processing Record 5 of Set 12 | namibe
# Processing Record 6 of Set 12 | price
# Processing Record 7 of Set 12 | wattegama
# Processing Record 8 of Set 12 | hegang
# Processing Record 9 of Set 12 | beohari
# Processing Record 10 of Set 12 | phalodi
# Processing Record 11 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 12 | salinopolis
# Processing Record 13 of Set 12 | juybar
# Processing Record 14 of Set 12 | sisimiut
# Processing Record 15 of Set 12 | tairua
# Processing Record 16 of Set 12 | grand forks
# Processing Record 17 of Set 12 | cheremukhovo
# Processing Record 18 of Set 12 | auki
# Processing Record 19 of Set 12 | catubig
# Processing Record 20 of Set 12 | dunedin
# Processing Record 21 of Set 12 | puerto carreno
# Processing Record 22 of Set 12 | kuusamo
# Processing Record 23 of Set 12 | morganton
# Processing Record 24 of Set 12 | scarborough
# Processing Record 25 of Set 12 | hobyo
# Processing Record 26 of Set 12 | rybnaya sloboda
# Processing Record 27 of Set 12 | emerald
# Processing Record 28 of Set 12 | itoman
# Processing Record 29 of Set 12 | nantucket
# Processing Record 30 of Set 12 | snyder
# Processing Record 31 of Set 12 | gouyave
# Processing Record 32 of Set 12 | aitape
# Processing Record 33 of Set 12 | henties bay
# Processing Record 34 of Set 12 | tautira
# Processing Record 35 of Set 12 | beloha
# Processing Record 36 of Set 12 | gushikawa
# Processing Record 37 of Set 12 | moose factory
# Processing Record 38 of Set 12 | rockland
# Processing Record 39 of Set 12 | agadez
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | buraydah
# Processing Record 42 of Set 12 | amantea
# Processing Record 43 of Set 12 | rockport
# Processing Record 44 of Set 12 | mandiana
# Processing Record 45 of Set 12 | aksha
# Processing Record 46 of Set 12 | turkistan
# Processing Record 47 of Set 12 | opatija
# Processing Record 48 of Set 12 | kinablangan
# Processing Record 49 of Set 12 | dandong
# Processing Record 50 of Set 12 | cakovec
# Processing Record 1 of Set 13 | mahajanga
# Processing Record 2 of Set 13 | magpet
# Processing Record 3 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 13 | sokolka
# Processing Record 5 of Set 13 | leopold
# Processing Record 6 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 7 of Set 13 | solnechnyy
# Processing Record 8 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 13 | metro
# Processing Record 10 of Set 13 | treinta y tres
# Processing Record 11 of Set 13 | santiago del estero
# Processing Record 12 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 13 | soe
# Processing Record 14 of Set 13 | le locle
# Processing Record 15 of Set 13 | buchanan
# Processing Record 16 of Set 13 | sirhind
# Processing Record 17 of Set 13 | nhulunbuy
# Processing Record 18 of Set 13 | suntar
# Processing Record 19 of Set 13 | zempoala
# Processing Record 20 of Set 13 | scottsbluff
# Processing Record 21 of Set 13 | batagay-alyta
# Processing Record 22 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 13 | tigil
# Processing Record 24 of Set 13 | schattdorf
# Processing Record 25 of Set 13 | salalah
# Processing Record 26 of Set 13 | edgewater
# Processing Record 27 of Set 13 | joao pinheiro
# Processing Record 28 of Set 13 | sidi ali
# Processing Record 29 of Set 13 | elko
# Processing Record 30 of Set 13 | awjilah
# Processing Record 31 of Set 13 | dire
# Processing Record 32 of Set 13 | jerome
# Processing Record 33 of Set 13 | ndele
# Processing Record 34 of Set 13 | montrose
# Processing Record 35 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 13 | baculin
# Processing Record 37 of Set 13 | chermoz
# Processing Record 38 of Set 13 | yar-sale
# Processing Record 39 of Set 13 | muros
# Processing Record 40 of Set 13 | wenatchee
# Processing Record 41 of Set 13 | port hedland
# Processing Record 42 of Set 13 | sao felix do xingu
# Processing Record 43 of Set 13 | zhuhai
# Processing Record 44 of Set 13 | richards bay
# Processing Record 45 of Set 13 | mikkeli
# Processing Record 46 of Set 13 | akyab
# Processing Record 47 of Set 13 | omsukchan
# Processing Record 48 of Set 13 | le port
# Processing Record 49 of Set 13 | ola
# Processing Record 50 of Set 13 | igarka
# Processing Record 1 of Set 14 | phan thiet
# Processing Record 2 of Set 14 | mitu
# Processing Record 3 of Set 14 | aklavik
# Processing Record 4 of Set 14 | la ronge
# Processing Record 5 of Set 14 | gallup
# Processing Record 6 of Set 14 | pisco
# Processing Record 7 of Set 14 | fare
# Processing Record 8 of Set 14 | shellbrook
# Processing Record 9 of Set 14 | lavrentiya
# Processing Record 10 of Set 14 | balancan
# Processing Record 11 of Set 14 | ulladulla
# Processing Record 12 of Set 14 | pimentel
# Processing Record 13 of Set 14 | sumkino
# Processing Record 14 of Set 14 | pedernales
# Processing Record 15 of Set 14 | bowmore
# Processing Record 16 of Set 14 | san jeronimo
# Processing Record 17 of Set 14 | aasiaat
# Processing Record 18 of Set 14 | inuvik
# Processing Record 19 of Set 14 | marawi
# Processing Record 20 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 14 | puerto penasco
# Processing Record 22 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 23 of Set 14 | wolmaranstad
# City not found. Skipping...
# Processing Record 24 of Set 14 | ural
# Processing Record 25 of Set 14 | aneho
# Processing Record 26 of Set 14 | prevalje
# Processing Record 27 of Set 14 | cinnaminson
# Processing Record 28 of Set 14 | camana
# Processing Record 29 of Set 14 | burica
# City not found. Skipping...
# Processing Record 30 of Set 14 | krasnyy yar
# Processing Record 31 of Set 14 | nuevo progreso
# Processing Record 32 of Set 14 | naryan-mar
# Processing Record 33 of Set 14 | marystown
# Processing Record 34 of Set 14 | san carlos
# Processing Record 35 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 14 | contamana
# Processing Record 37 of Set 14 | bantry
# Processing Record 38 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 14 | ambon
# Processing Record 40 of Set 14 | koumac
# Processing Record 41 of Set 14 | bend
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | santa maria
# Processing Record 44 of Set 14 | georgiyevka
# Processing Record 45 of Set 14 | cayenne
# Processing Record 46 of Set 14 | marsabit
# Processing Record 47 of Set 14 | puerto quijarro
# Processing Record 48 of Set 14 | perth
# Processing Record 49 of Set 14 | bonfim
# Processing Record 50 of Set 14 | broome
# Processing Record 1 of Set 15 | zarubino
# Processing Record 2 of Set 15 | anton lizardo
# Processing Record 3 of Set 15 | axim
# Processing Record 4 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 15 | fort nelson
# Processing Record 6 of Set 15 | jagdalpur
# Processing Record 7 of Set 15 | rome
# Processing Record 8 of Set 15 | klaksvik
# Processing Record 9 of Set 15 | kununurra
# Processing Record 10 of Set 15 | bahia blanca
# Processing Record 11 of Set 15 | harnoli
# Processing Record 12 of Set 15 | dapaong
# Processing Record 13 of Set 15 | phnum penh
# City not found. Skipping...
# Processing Record 14 of Set 15 | emba
# Processing Record 15 of Set 15 | cabungahan
# Processing Record 16 of Set 15 | alexandria
# Processing Record 17 of Set 15 | avera
# Processing Record 18 of Set 15 | zlitan
# Processing Record 19 of Set 15 | komsomolskiy
# Processing Record 20 of Set 15 | aguimes
# Processing Record 21 of Set 15 | winslow
# Processing Record 22 of Set 15 | zyryanka
# Processing Record 23 of Set 15 | katsina
# Processing Record 24 of Set 15 | tezu
# Processing Record 25 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 15 | remontnoye
# Processing Record 27 of Set 15 | wadena
# Processing Record 28 of Set 15 | bay roberts
# Processing Record 29 of Set 15 | wajir
# Processing Record 30 of Set 15 | zaqatala
# Processing Record 31 of Set 15 | brus laguna
# Processing Record 32 of Set 15 | sioux lookout
# Processing Record 33 of Set 15 | lalin
# Processing Record 34 of Set 15 | cabra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Vaini -21.20 -175.20     80.60        74          75        8.05
# 1           Sorong  -0.88  131.25     85.08        62          88        5.21
# 2          Rikitea -23.12 -134.97     75.87        65          76        5.14
# 3  Sherlovaya Gora  50.57  116.25      4.48        91           0        7.58
# 4      New Norfolk -42.78  147.06     64.99        50           0        5.99
# 5  Arraial Do Cabo -22.97  -42.03     75.16        88          90        6.82
# 6        Bathsheba  13.22  -59.52     78.80        78          20       11.41
# 7          Svetlyy  54.67   20.13     23.00        92           2        4.47
# 8           Anadyr  64.75  177.48    -18.40        82          75        4.47
# 9   Cap-Aux-Meules  47.38  -61.86     50.00        87         100       19.46
#
#   Country Current Description                 Date
# 0      TO       broken clouds  2020-12-02 03:23:20
# 1      ID     overcast clouds  2020-12-02 03:19:01
# 2      PF       broken clouds  2020-12-02 03:23:20
# 3      RU           clear sky  2020-12-02 03:23:20
# 4      AU           clear sky  2020-12-02 03:23:20
# 5      BR     overcast clouds  2020-12-02 03:23:20
# 6      BB          few clouds  2020-12-02 03:13:56
# 7      RU           clear sky  2020-12-02 03:23:21
# 8      RU                 fog  2020-12-02 03:23:21
# 9      CA     overcast clouds  2020-12-02 03:23:21

# %%
new_coloum_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_coloum_order]
city_data_df.head()
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO -21.20 -175.20     80.60        74          75
# 1           Sorong      ID  -0.88  131.25     85.08        62          88
# 2          Rikitea      PF -23.12 -134.97     75.87        65          76
# 3  Sherlovaya Gora      RU  50.57  116.25      4.48        91           0
# 4      New Norfolk      AU -42.78  147.06     64.99        50           0
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1        5.21     overcast clouds
# 2        5.14       broken clouds
# 3        7.58           clear sky
# 4        5.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
